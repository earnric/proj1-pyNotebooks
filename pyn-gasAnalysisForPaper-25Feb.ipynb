# %% [markdown]
# # Plots for paper

# %%
# %matplotlib inline
import gc
# %config InlineBackend.figure_format = 'retina'
from matplotlib.pylab import *
import matplotlib.pyplot as plt 
rcParams['figure.figsize'] = (12,9)
rcParams['font.size'] = 34
#import logging

# %%
import pynbody
import pynbody.plot.sph as sph
import mmap
pynbody.ramses.multiprocess_num = 12
pynbody.config['number_of_threads'] = 24

# %%
pynbody.openmp.get_cpus()
# Out:
# 24

# %% [markdown]
# ## We need output 16 and 121 for the paper ... These correspond to z = 16 and z = 8 respectively

# %%
gc.collect()
# Out:
# 66

# %%
#s = pynbody.load('output_00016')
s = pynbody.load('output_00121')
s['pos']
s['pos'] -= 0.5
s.physical_units();
# Out:
# /Users/earnric/anaconda/lib/python3.4/site-packages/pynbody/snapshot/ramses.py:521: UserWarning: Using field 'tform' to distinguish stars. If this is wrong, try editing your config.ini, section [ramses], entry particle-distinguisher.
#   warnings.warn("Using field %s to distinguish stars. If this is wrong, try editing your config.ini, section [ramses], entry particle-distinguisher."%pb_name)

# %%
z = 1/s.properties['a']-1
print ("Redshift =",z)
boxsizestring = "%.2f" % s.properties['boxsize'].in_units('kpc')
boxsizestring += " kpc"
print (boxsizestring)
# Out:
# Redshift = 7.999933327855002
# 468.62 kpc

# %%
s.s['mass'].max()
# Out:
# SimArray(3627.9567907555975, 'Msol')

# %%
s.g['zsolar']  = s.g['metal'] * 50.0         # Solar units
s.g['pzsolar'] = s.g['pzf'] * 50.0           # Solar units

s.g['zsolar'][s.g['zsolar']< 1e-5] = 1e-6
s.g['pzsolar'][s.g['pzsolar']< 1e-5] = 1e-6

# %%
#sbox = 40.0 / (1.0 + z) * 0.71 # 40 kpc comoving box
sbox = 200.0 / (1.0 + z) * 0.71 # 40 kpc comoving box
smallbox = str(sbox) + " kpc"
print(smallbox)
# Out:
# 15.77789466067562 kpc

# %%
# z=16, i=0 : -20.26, -122.12, 40.22
# z=16, i=770 : 43.96, 26.56, 121.94
# z=16, i=1540 : 44.54, 19.03, 118.77

# rx,ry,rz = 44.54, 19.03, 118.77
# i=1540
# print(rx,ry,rz)

# z=8
# z=8, i=0 : -121.77, -104.01, -203.10
# z=8, i=265793 : -0.88, 215.56, 143.27
# z=8, i=531586 : 77.55, 54.08, 218.96
# z=8, i=797379 : 137.45, -200.82, -220.27

rx,ry,rz = -0.88, 215.56, 143.27
tic = (5,3,1)
i=265793

impData = s[pynbody.filt.Cuboid(str((rx-sbox/2.0)) + " kpc", str((ry-sbox/2.0)) + " kpc",str((rz-sbox/4.0)) + " kpc",
                                str((rx+sbox/2.0)) + " kpc", str((ry+sbox/2.0)) + " kpc",str((rz+sbox/4.0)) + " kpc")]

# %%
tic = 3.5

# %%
print(z,i)
impData.g['pgf']
print(impData.g['pgf'].max())
# Out:
# 7.999933327855002 265793
# 0.99999999999629

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    try: 
        fig = plt.figure()
        ax = fig.add_subplot(111)
        fileOut = "img_log_ax_PGF-z=%.1lf-%i.pdf"% (z,i)
        titleStr = "PGF - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
        print (titleStr)
        sph.image(impData.g,qty="pgf",width=smallbox,cmap="nipy_spectral", denoise=True ,av_z=False, subplot=ax,
                log=True, vmax = 1.0, vmin=1e-6, qtytitle=r"${\rm log}\, P}$",approximate_fast=False);
        ax.set_xticks([-tic, 0, tic])
        ax.set_yticks([-tic, 0, tic])
        plt.savefig(fileOut,dpi=fig.dpi,bbox_inches='tight')
        plt.close(fig)
        del(ax)
    except:
        print("Unable to make PGF plot")
        pass
# Out:
# PGF - z = 8.0
# Unable to make PGF plot

# %%
20/ (1.0 + z) * 0.71
# Out:
# 1.5777894660675618

# %%
from mpl_toolkits.axes_grid.anchored_artists import AnchoredDrawingArea
from mpl_toolkits.axes_grid.anchored_artists import AnchoredAuxTransformBox
from matplotlib.patches import Rectangle, Ellipse

rect = [0.15,0.15,0.85,0.9]
coords= [-rx,-ry,-rz] # Translation requires negative of the coord

with pynbody.transformation.translate(impData,coords):

    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.xaxis.set_visible(False)
    fileOut = "img_log_ax_Density-z=%.1lf-%i_withBox3.pdf"% (z,i)
    titleStr = "Density - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="rho",width=smallbox,cmap="terrain", denoise=True ,av_z=False, units="m_p cm^-3",
                      log=True, approximate_fast=False, vmin=10**-4.5, vmax=10**2.0,
                      subplot=ax,qtytitle=r"${\rm log}\,m_{\rm p}/{\rm cm}^{3}$"); 
    ax.set_yticks([-tic, 0,tic])

    currentAxis = plt.gca()
    currentAxis.add_patch(Rectangle((-.7535, -.7535), 1.578, 1.578, facecolor="grey", alpha=0.35))
    bbox = {'facecolor':'white', 'alpha':0.0, 'pad':3}
    ax.annotate("Star forming region",xy=( -.7535,0.0),
                arrowprops=dict(arrowstyle="->", facecolor='black', shrinkB=5,connectionstyle="arc3,rad=-0.2"), 
                xytext=(-4,-3.), horizontalalignment='center', verticalalignment="center", bbox=bbox, size=24)

    
    plt.savefig(fileOut,dpi=fig.dpi,bbox_inches='tight')
    plt.show()
    #plt.close(fig)
# Out:
# Density - z = 8.0
# /Users/earnric/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
del(ax)
gc.collect()
# Out:
# 30633

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.yaxis.set_visible(False)
    #ax.set_xlabel(fontsize=40)
    fileOut = "img_log_ax_Z-z=%.1lf-%i.pdf"% (z,i)
    titleStr = r"$Z_{\odot}$ - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="zsolar",width=smallbox,cmap="nipy_spectral", denoise=True ,av_z=False, subplot=ax,
                      log=True, vmax=1.0, vmin=1e-6, qtytitle=r"${\rm log}\, \overline{Z}/Z_{\odot}$",
                      approximate_fast=False); #vmin=0.006, vmax=1.0,
    ax.set_xticks([-tic, 0, tic])
    plt.savefig(fileOut, dpi=fig.dpi, bbox_inches='tight')
    print ("Save filename:", fileOut)
    plt.close(fig)
    del(ax)
    gc.collect()
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.yaxis.set_visible(False)
    fileOut = "img_log_ax_PZ-z=%.1lf-%i.pdf"% (z,i)
    titleStr = r"$Z_{P, \odot}$ - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="pzsolar",width=smallbox,cmap="nipy_spectral", denoise=True ,av_z=False,subplot=ax,
                      log=True, vmax=1.0, vmin=1e-6, qtytitle=r"${\rm log}\,\overline{Z_{P}}/Z_{\odot}$",
                      approximate_fast=False );
    ax.set_xticks([-tic, 0, tic])
    plt.savefig(fileOut,dpi=fig.dpi,bbox_inches='tight')
    plt.close(fig)
    del(ax)

#     fig = plt.figure()
#     ax = fig.add_subplot(111)
#     ax.xaxis.set_visible(False)
#     fileOut = "img_log_ax_Density-z=%.1lf-%i.pdf"% (z,i)
#     titleStr = "Density - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
#     print (titleStr)
#     sph.image(impData.g,qty="rho",width=smallbox,cmap="terrain", denoise=True ,av_z=False, units="m_p cm^-3",
#                       log=True, approximate_fast=False, vmin=10**-4.5, vmax=10**2.0,
#                       subplot=ax,qtytitle=r"${\rm log}\,m_{\rm p}/{\rm cm}^{3}$"); 
#     ax.set_yticks([-tic, 0,tic])
#     plt.savefig(fileOut,dpi=fig.dpi,bbox_inches='tight')
#     plt.close(fig)
#     del(ax)
#     gc.collect()

#     fig = plt.figure()
#     ax = fig.add_subplot(111)
#     ax.xaxis.set_visible(False)
#     ax.yaxis.set_visible(False)
#     fileOut = "img_log_ax_cs-z=%.1lf-%i.pdf"% (z,i)
#     titleStr = "cs - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
#     print (titleStr)
#     sph.image(impData.g,qty="cs",width=smallbox,cmap="RdYlBu_r", denoise=True ,av_z=False, units="km s^-1",
#                       log=True, approximate_fast=False,subplot=ax,  vmin=10**0.5, vmax=1e3,
#                       qtytitle=r"${\rm log}\, c_{\rm s}\, {\rm km/s}$"); 
#     plt.savefig(fileOut,dpi=fig.dpi,bbox_inches='tight') 
#     plt.close(fig)
#     del(ax)
    
#     fig = plt.figure()
#     ax = fig.add_subplot(111)
#     ax.xaxis.set_visible(False)
#     ax.yaxis.set_visible(False)
#     fileOut = "img_log_ax_vt-z=%.1lf-%i.pdf"% (z,i)
#     titleStr = "$v_{t}$ @ z = %.1f" % z + "\nThin slice @ %s" % str(coords)
#     print(titleStr)
#     sph.velocity_image(impData.g, qty="tv", width=smallbox, cmap = "RdYlBu_r", units="km s^-1",
#                    mode='quiver', quiverkey=False,qtytitle=r"${\rm log}\, v_{t}\, {\rm km/s}$",
#                    density = 1.0, vector_resolution=40, vmin=10**0.5, vmax=1e3, subplot=ax,
#                    show_cbar=True, vector_color='black') # gist_ncar
#     plt.savefig(fileOut,dpi=fig.dpi,bbox_inches='tight') 
#     plt.close(fig)
#     del(ax)
#     gc.collect()
# Out:
# $Z_{\odot}$ - z = 8.0
# /Users/earnric/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# Save filename: /Users/earnric/img_log_ax_Z-z=8.0-265793.pdf
# $Z_{P, \odot}$ - z = 8.0

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    fileOut = "img_log_ax_T-z=%.1lf-%i.pdf"% (z,i)
    ax.set_xticks([-tic, 0, tic])
    ax.set_yticks([-tic, 0, tic])
    im = sph.image(impData.g,qty="temp",width=smallbox,cmap="RdYlBu_r", denoise=True ,av_z=False, #ret_im=True,
                   log=True, subplot=ax, approximate_fast=False,qtytitle=r"${\rm log}\; T/K$"
                   ,show_cbar=True
                  ); #vmin=0.006, vmax=1.0,
    #cbar = fig.colorbar(im)
    #plt.colorbar(im,format=custom_formatter)
    plt.savefig(fileOut,dpi=fig.dpi,bbox_inches='tight') 
    plt.show()

# %%
print(impData.g['vel'].max())
# Out:
# 360.268180242

# %%
hiVel = impData[pynbody.filt.BandPass('vel','200 km s**-1','500 km s**-1')]

# %%
hiVel['vel'].max()
# Out:
# SimArray(360.2681802424559, 'km s**-1')

# %%
print(np.sqrt(impData.g['vx']**2+impData.g['vy']**2).max())
print(np.sqrt(impData.g['vx']**2+impData.g['vy']**2+impData.g['vz']**2).max())
# Out:
# 538.594292271
# 624.44735069

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    fileOut="img_vt-z=%.1lf-%i_withLegend.pdf"% (z,i)
    titleStr = "$v_{t}$ @ z = %.1f" % z + "\nThin slice @ %s" % str(coords)
    print(titleStr)
    pynbody.plot.sph.velocity_image(impData.g, qty="tv", width=smallbox, cmap = "RdYlBu_r", 
                    mode='quiver', key_color='black',qtytitle="$log_{10}\; v\, km/s$",quiverkey_bg_color='w',
                    key_x=0.2, key_y=0.02,key_length="500 km s**-1",
                    density = 1.0, vector_resolution=40, vmax=1e3,subplot=ax,
                    show_cbar=True, vector_color='black')
    plt.show()
    plt.savefig(fileOut)  # Needed since filename=fileOut doesn't include the vel vecs
#    plt.close(fig)
# Out:
# $v_{t}$ @ z = 8.0
# Thin slice @ [0.88, -215.56, -143.27]

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    fileOut="img_vt-z=%.1lf-%i_withLegend.pdf"% (z,i)
    titleStr = "$v_{t}$ @ z = %.1f" % z + "\nThin slice @ %s" % str(coords)
    print(titleStr)
    pynbody.plot.sph.velocity_image(impData.g, qty="tv", width=smallbox, cmap = "RdYlBu_r", 
                    mode='stream', key_color='black',qtytitle="$log_{10}\; v\, km/s$",#quiverkey_bg_color='w',
                    #key_x=0.2, key_y=0.02,key_length="400 km s**-1",
                    density = 1.0, vector_resolution=40, vmax=1e3,subplot=ax,
                    show_cbar=True, vector_color='black')
    plt.show()
#    plt.savefig(fileOut)  # Needed since filename=fileOut doesn't include the vel vecs
#    plt.close(fig)
# Out:
# $v_{t}$ @ z = 8.0
# Thin slice @ [0.88, -215.56, -143.27]

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    fileOut="img_vt-z=%.1lf-%i_withLegend.pdf"% (z,i)
    titleStr = "$v_{t}$ @ z = %.1f" % z + "\nThin slice @ %s" % str(coords)
    print(titleStr)
    pynbody.plot.sph.velocity_image(impData.g, qty="tv", width='4.0 kpc', cmap = "RdYlBu_r", 
                    mode='quiver', key_color='black',qtytitle="$log_{10}\; v\, km/s$",quiverkey_bg_color='w',
                    key_x=0.2, key_y=0.02,key_length="300 km s**-1",
                    density = 1.0, vector_resolution=40, vmax=1e3,subplot=ax,
                    show_cbar=True, vector_color='black')
    plt.show()
#    plt.savefig(fileOut)  # Needed since filename=fileOut doesn't include the vel vecs
#    plt.close(fig)
# Out:
# $v_{t}$ @ z = 8.0
# Thin slice @ [0.88, -215.56, -143.27]

# %%
pynbody.analysis.angmom.faceon(impData,cen=(rx,ry,rz),disk_size='5 kpc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-576f4376b68f> in <module>()
# ----> 1 pynbody.analysis.angmom.faceon(impData,cen=(rx,ry,rz),disk_size='5 kpc')
#
# /Users/earnric/anaconda/envs/py27/lib/python2.7/site-packages/pynbody/analysis/angmom.pyc in faceon(h, **kwargs)
#     155     """
#     156
# --> 157     return sideon(h, calc_faceon_matrix, **kwargs)
#
# /Users/earnric/anaconda/envs/py27/lib/python2.7/site-packages/pynbody/analysis/angmom.pyc in sideon(h, vec_to_xform, cen_size, disk_size, cen, vcen, move_all, **kwargs)
#     120
#     121     if vcen is None:
# --> 122         vcen = halo.vel_center(h, retcen=True, cen_size=cen_size)
#     123
#     124     tx = transformation.inverse_v_translate(tx, vcen)
#
# /Users/earnric/anaconda/envs/py27/lib/python2.7/site-packages/pynbody/analysis/halo.pyc in vel_center(sim, mode, cen_size, retcen, move_all, **kwargs)
#     224     if len(cen) < 5:
#     225         # very weird snapshot, or mis-centering!
# --> 226         raise ValueError, "Insufficient particles around center to get velocity"
#     227
#     228     vcen = (cen['vel'].transpose() * cen['mass']).sum(axis=1) / \
#
# ValueError: Insufficient particles around center to get velocity

# %% [markdown]
# # Next

# %%
del(s)
gc.collect()

# %%
gc.collect()
# Out:
# 1110

# %%
s = pynbody.load('output_00121')
s['pos']
s['pos'] -= 0.5
s.physical_units();
# Out:
# INFO:pynbody:Loading using backend <class 'pynbody.snapshot.ramses.RamsesSnap'>
# INFO:pynbody.snapshot.ramses:Loading hydro files
# INFO:pynbody.snapshot.ramses:Done
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1
# INFO:pynbody.snapshot.ramses:Loading data from CPU 23
# INFO:pynbody.snapshot.ramses:Loading data from CPU 45
# INFO:pynbody.snapshot.ramses:Loading data from CPU 67
# INFO:pynbody.snapshot.ramses:Loading data from CPU 89
# INFO:pynbody.snapshot.ramses:Loading data from CPU 111
# INFO:pynbody.snapshot.ramses:Loading data from CPU 133
# INFO:pynbody.snapshot.ramses:Loading data from CPU 155
# INFO:pynbody.snapshot.ramses:Loading data from CPU 177
# INFO:pynbody.snapshot.ramses:Loading data from CPU 199
# INFO:pynbody.snapshot.ramses:Loading data from CPU 221
# INFO:pynbody.snapshot.ramses:Loading data from CPU 243
# INFO:pynbody.snapshot.ramses:Loading data from CPU 2
# INFO:pynbody.snapshot.ramses:Loading data from CPU 24
# INFO:pynbody.snapshot.ramses:Loading data from CPU 46
# INFO:pynbody.snapshot.ramses:Loading data from CPU 68
# INFO:pynbody.snapshot.ramses:Loading data from CPU 90
# INFO:pynbody.snapshot.ramses:Loading data from CPU 112
# INFO:pynbody.snapshot.ramses:Loading data from CPU 134
# INFO:pynbody.snapshot.ramses:Loading data from CPU 156
# INFO:pynbody.snapshot.ramses:Loading data from CPU 178
# INFO:pynbody.snapshot.ramses:Loading data from CPU 200
# INFO:pynbody.snapshot.ramses:Loading data from CPU 222
# INFO:pynbody.snapshot.ramses:Loading data from CPU 244
# INFO:pynbody.snapshot.ramses:Loading data from CPU 3
# INFO:pynbody.snapshot.ramses:Loading data from CPU 25
# INFO:pynbody.snapshot.ramses:Loading data from CPU 47
# INFO:pynbody.snapshot.ramses:Loading data from CPU 69
# INFO:pynbody.snapshot.ramses:Loading data from CPU 91
# INFO:pynbody.snapshot.ramses:Loading data from CPU 113
# INFO:pynbody.snapshot.ramses:Loading data from CPU 135
# INFO:pynbody.snapshot.ramses:Loading data from CPU 157
# INFO:pynbody.snapshot.ramses:Loading data from CPU 179
# INFO:pynbody.snapshot.ramses:Loading data from CPU 201
# INFO:pynbody.snapshot.ramses:Loading data from CPU 223
# INFO:pynbody.snapshot.ramses:Loading data from CPU 245
# INFO:pynbody.snapshot.ramses:Loading data from CPU 4
# INFO:pynbody.snapshot.ramses:Loading data from CPU 26
# INFO:pynbody.snapshot.ramses:Loading data from CPU 48
# INFO:pynbody.snapshot.ramses:Loading data from CPU 70
# INFO:pynbody.snapshot.ramses:Loading data from CPU 92
# INFO:pynbody.snapshot.ramses:Loading data from CPU 114
# INFO:pynbody.snapshot.ramses:Loading data from CPU 136
# INFO:pynbody.snapshot.ramses:Loading data from CPU 158
# INFO:pynbody.snapshot.ramses:Loading data from CPU 180
# INFO:pynbody.snapshot.ramses:Loading data from CPU 202
# INFO:pynbody.snapshot.ramses:Loading data from CPU 224
# INFO:pynbody.snapshot.ramses:Loading data from CPU 246
# INFO:pynbody.snapshot.ramses:Loading data from CPU 5
# INFO:pynbody.snapshot.ramses:Loading data from CPU 27
# INFO:pynbody.snapshot.ramses:Loading data from CPU 49
# INFO:pynbody.snapshot.ramses:Loading data from CPU 71
# INFO:pynbody.snapshot.ramses:Loading data from CPU 93
# INFO:pynbody.snapshot.ramses:Loading data from CPU 115
# INFO:pynbody.snapshot.ramses:Loading data from CPU 137
# INFO:pynbody.snapshot.ramses:Loading data from CPU 159
# INFO:pynbody.snapshot.ramses:Loading data from CPU 181
# INFO:pynbody.snapshot.ramses:Loading data from CPU 203
# INFO:pynbody.snapshot.ramses:Loading data from CPU 225
# INFO:pynbody.snapshot.ramses:Loading data from CPU 247
# INFO:pynbody.snapshot.ramses:Loading data from CPU 6
# INFO:pynbody.snapshot.ramses:Loading data from CPU 28
# INFO:pynbody.snapshot.ramses:Loading data from CPU 50
# INFO:pynbody.snapshot.ramses:Loading data from CPU 72
# INFO:pynbody.snapshot.ramses:Loading data from CPU 94
# INFO:pynbody.snapshot.ramses:Loading data from CPU 116
# INFO:pynbody.snapshot.ramses:Loading data from CPU 138
# INFO:pynbody.snapshot.ramses:Loading data from CPU 160
# INFO:pynbody.snapshot.ramses:Loading data from CPU 182
# INFO:pynbody.snapshot.ramses:Loading data from CPU 204
# INFO:pynbody.snapshot.ramses:Loading data from CPU 226
# INFO:pynbody.snapshot.ramses:Loading data from CPU 248
# INFO:pynbody.snapshot.ramses:Loading data from CPU 7
# INFO:pynbody.snapshot.ramses:Loading data from CPU 29
# INFO:pynbody.snapshot.ramses:Loading data from CPU 51
# INFO:pynbody.snapshot.ramses:Loading data from CPU 73
# INFO:pynbody.snapshot.ramses:Loading data from CPU 95
# INFO:pynbody.snapshot.ramses:Loading data from CPU 117
# INFO:pynbody.snapshot.ramses:Loading data from CPU 139
# INFO:pynbody.snapshot.ramses:Loading data from CPU 161
# INFO:pynbody.snapshot.ramses:Loading data from CPU 183
# INFO:pynbody.snapshot.ramses:Loading data from CPU 205
# INFO:pynbody.snapshot.ramses:Loading data from CPU 227
# INFO:pynbody.snapshot.ramses:Loading data from CPU 249
# INFO:pynbody.snapshot.ramses:Loading data from CPU 8
# INFO:pynbody.snapshot.ramses:Loading data from CPU 30
# INFO:pynbody.snapshot.ramses:Loading data from CPU 52
# INFO:pynbody.snapshot.ramses:Loading data from CPU 74
# INFO:pynbody.snapshot.ramses:Loading data from CPU 96
# INFO:pynbody.snapshot.ramses:Loading data from CPU 118
# INFO:pynbody.snapshot.ramses:Loading data from CPU 140
# INFO:pynbody.snapshot.ramses:Loading data from CPU 162
# INFO:pynbody.snapshot.ramses:Loading data from CPU 184
# INFO:pynbody.snapshot.ramses:Loading data from CPU 206
# INFO:pynbody.snapshot.ramses:Loading data from CPU 228
# INFO:pynbody.snapshot.ramses:Loading data from CPU 250
# INFO:pynbody.snapshot.ramses:Loading data from CPU 9
# INFO:pynbody.snapshot.ramses:Loading data from CPU 31
# INFO:pynbody.snapshot.ramses:Loading data from CPU 53
# INFO:pynbody.snapshot.ramses:Loading data from CPU 75
# INFO:pynbody.snapshot.ramses:Loading data from CPU 97
# INFO:pynbody.snapshot.ramses:Loading data from CPU 119
# INFO:pynbody.snapshot.ramses:Loading data from CPU 141
# INFO:pynbody.snapshot.ramses:Loading data from CPU 163
# INFO:pynbody.snapshot.ramses:Loading data from CPU 185
# INFO:pynbody.snapshot.ramses:Loading data from CPU 207
# INFO:pynbody.snapshot.ramses:Loading data from CPU 229
# INFO:pynbody.snapshot.ramses:Loading data from CPU 251
# INFO:pynbody.snapshot.ramses:Loading data from CPU 10
# INFO:pynbody.snapshot.ramses:Loading data from CPU 32
# INFO:pynbody.snapshot.ramses:Loading data from CPU 54
# INFO:pynbody.snapshot.ramses:Loading data from CPU 76
# INFO:pynbody.snapshot.ramses:Loading data from CPU 98
# INFO:pynbody.snapshot.ramses:Loading data from CPU 120
# INFO:pynbody.snapshot.ramses:Loading data from CPU 142
# INFO:pynbody.snapshot.ramses:Loading data from CPU 164
# INFO:pynbody.snapshot.ramses:Loading data from CPU 186
# INFO:pynbody.snapshot.ramses:Loading data from CPU 208
# INFO:pynbody.snapshot.ramses:Loading data from CPU 230
# INFO:pynbody.snapshot.ramses:Loading data from CPU 252
# INFO:pynbody.snapshot.ramses:Loading data from CPU 11
# INFO:pynbody.snapshot.ramses:Loading data from CPU 33
# INFO:pynbody.snapshot.ramses:Loading data from CPU 55
# INFO:pynbody.snapshot.ramses:Loading data from CPU 77
# INFO:pynbody.snapshot.ramses:Loading data from CPU 99
# INFO:pynbody.snapshot.ramses:Loading data from CPU 121
# INFO:pynbody.snapshot.ramses:Loading data from CPU 143
# INFO:pynbody.snapshot.ramses:Loading data from CPU 165
# INFO:pynbody.snapshot.ramses:Loading data from CPU 187
# INFO:pynbody.snapshot.ramses:Loading data from CPU 209
# INFO:pynbody.snapshot.ramses:Loading data from CPU 231
# INFO:pynbody.snapshot.ramses:Loading data from CPU 253
# INFO:pynbody.snapshot:Converting pos units from 1.45e+24 cm to kpc
# INFO:pynbody.snapshot.ramses:Loading data from CPU 12
# INFO:pynbody.snapshot.ramses:Loading data from CPU 34
# INFO:pynbody.snapshot.ramses:Loading data from CPU 56
# INFO:pynbody.snapshot.ramses:Loading data from CPU 78
# INFO:pynbody.snapshot.ramses:Loading data from CPU 100
# INFO:pynbody.snapshot.ramses:Loading data from CPU 122
# INFO:pynbody.snapshot.ramses:Loading data from CPU 144
# INFO:pynbody.snapshot.ramses:Loading data from CPU 166
# INFO:pynbody.snapshot.ramses:Loading data from CPU 188
# INFO:pynbody.snapshot.ramses:Loading data from CPU 210
# INFO:pynbody.snapshot.ramses:Loading data from CPU 232
# INFO:pynbody.snapshot.ramses:Loading data from CPU 254
# INFO:pynbody.snapshot.ramses:Loading data from CPU 13
# INFO:pynbody.snapshot.ramses:Loading data from CPU 35
# INFO:pynbody.snapshot.ramses:Loading data from CPU 57
# INFO:pynbody.snapshot.ramses:Loading data from CPU 79
# INFO:pynbody.snapshot.ramses:Loading data from CPU 101
# INFO:pynbody.snapshot.ramses:Loading data from CPU 123
# INFO:pynbody.snapshot.ramses:Loading data from CPU 145
# INFO:pynbody.snapshot.ramses:Loading data from CPU 167
# INFO:pynbody.snapshot.ramses:Loading data from CPU 189
# INFO:pynbody.snapshot.ramses:Loading data from CPU 211
# INFO:pynbody.snapshot.ramses:Loading data from CPU 233
# INFO:pynbody.snapshot.ramses:Loading data from CPU 255
# INFO:pynbody.snapshot.ramses:Loading data from CPU 14
# INFO:pynbody.snapshot.ramses:Loading data from CPU 36
# INFO:pynbody.snapshot.ramses:Loading data from CPU 58
# INFO:pynbody.snapshot.ramses:Loading data from CPU 80
# INFO:pynbody.snapshot.ramses:Loading data from CPU 102
# INFO:pynbody.snapshot.ramses:Loading data from CPU 124
# INFO:pynbody.snapshot.ramses:Loading data from CPU 146
# INFO:pynbody.snapshot.ramses:Loading data from CPU 168
# INFO:pynbody.snapshot.ramses:Loading data from CPU 190
# INFO:pynbody.snapshot.ramses:Loading data from CPU 212
# INFO:pynbody.snapshot.ramses:Loading data from CPU 234
# INFO:pynbody.snapshot.ramses:Loading data from CPU 256
# INFO:pynbody.snapshot.ramses:Loading data from CPU 15
# INFO:pynbody.snapshot.ramses:Loading data from CPU 37
# INFO:pynbody.snapshot.ramses:Loading data from CPU 59
# INFO:pynbody.snapshot.ramses:Loading data from CPU 81
# INFO:pynbody.snapshot.ramses:Loading data from CPU 103
# INFO:pynbody.snapshot.ramses:Loading data from CPU 125
# INFO:pynbody.snapshot.ramses:Loading data from CPU 147
# INFO:pynbody.snapshot.ramses:Loading data from CPU 169
# INFO:pynbody.snapshot.ramses:Loading data from CPU 191
# INFO:pynbody.snapshot.ramses:Loading data from CPU 213
# INFO:pynbody.snapshot.ramses:Loading data from CPU 235
# INFO:pynbody.snapshot.ramses:Loading data from CPU 257
# INFO:pynbody.snapshot.ramses:Loading data from CPU 16
# INFO:pynbody.snapshot.ramses:Loading data from CPU 38
# INFO:pynbody.snapshot.ramses:Loading data from CPU 60
# INFO:pynbody.snapshot.ramses:Loading data from CPU 82
# INFO:pynbody.snapshot.ramses:Loading data from CPU 104
# INFO:pynbody.snapshot.ramses:Loading data from CPU 126
# INFO:pynbody.snapshot.ramses:Loading data from CPU 148
# INFO:pynbody.snapshot.ramses:Loading data from CPU 170
# INFO:pynbody.snapshot.ramses:Loading data from CPU 192
# INFO:pynbody.snapshot.ramses:Loading data from CPU 214
# INFO:pynbody.snapshot.ramses:Loading data from CPU 236
# INFO:pynbody.snapshot.ramses:Loading data from CPU 258
# INFO:pynbody.snapshot.ramses:Loading data from CPU 17
# INFO:pynbody.snapshot.ramses:Loading data from CPU 39
# INFO:pynbody.snapshot.ramses:Loading data from CPU 61
# INFO:pynbody.snapshot.ramses:Loading data from CPU 83
# INFO:pynbody.snapshot.ramses:Loading data from CPU 105
# INFO:pynbody.snapshot.ramses:Loading data from CPU 127
# INFO:pynbody.snapshot.ramses:Loading data from CPU 149
# INFO:pynbody.snapshot.ramses:Loading data from CPU 171
# INFO:pynbody.snapshot.ramses:Loading data from CPU 193
# INFO:pynbody.snapshot.ramses:Loading data from CPU 215
# INFO:pynbody.snapshot.ramses:Loading data from CPU 237
# INFO:pynbody.snapshot.ramses:Loading data from CPU 259
# INFO:pynbody.snapshot.ramses:Loading data from CPU 18
# INFO:pynbody.snapshot.ramses:Loading data from CPU 40
# INFO:pynbody.snapshot.ramses:Loading data from CPU 62
# INFO:pynbody.snapshot.ramses:Loading data from CPU 84
# INFO:pynbody.snapshot.ramses:Loading data from CPU 106
# INFO:pynbody.snapshot.ramses:Loading data from CPU 128
# INFO:pynbody.snapshot.ramses:Loading data from CPU 150
# INFO:pynbody.snapshot.ramses:Loading data from CPU 172
# INFO:pynbody.snapshot.ramses:Loading data from CPU 194
# INFO:pynbody.snapshot.ramses:Loading data from CPU 216
# INFO:pynbody.snapshot.ramses:Loading data from CPU 238
# INFO:pynbody.snapshot.ramses:Loading data from CPU 260
# INFO:pynbody.snapshot.ramses:Loading data from CPU 19
# INFO:pynbody.snapshot.ramses:Loading data from CPU 41
# INFO:pynbody.snapshot.ramses:Loading data from CPU 63
# INFO:pynbody.snapshot.ramses:Loading data from CPU 85
# INFO:pynbody.snapshot.ramses:Loading data from CPU 107
# INFO:pynbody.snapshot.ramses:Loading data from CPU 129
# INFO:pynbody.snapshot.ramses:Loading data from CPU 151
# INFO:pynbody.snapshot.ramses:Loading data from CPU 173
# INFO:pynbody.snapshot.ramses:Loading data from CPU 195
# INFO:pynbody.snapshot.ramses:Loading data from CPU 217
# INFO:pynbody.snapshot.ramses:Loading data from CPU 239
# INFO:pynbody.snapshot.ramses:Loading data from CPU 261
# INFO:pynbody.snapshot.ramses:Loading data from CPU 20
# INFO:pynbody.snapshot.ramses:Loading data from CPU 42
# INFO:pynbody.snapshot.ramses:Loading data from CPU 64
# INFO:pynbody.snapshot.ramses:Loading data from CPU 86
# INFO:pynbody.snapshot.ramses:Loading data from CPU 108
# INFO:pynbody.snapshot.ramses:Loading data from CPU 130
# INFO:pynbody.snapshot.ramses:Loading data from CPU 152
# INFO:pynbody.snapshot.ramses:Loading data from CPU 174
# INFO:pynbody.snapshot.ramses:Loading data from CPU 196
# INFO:pynbody.snapshot.ramses:Loading data from CPU 218
# INFO:pynbody.snapshot.ramses:Loading data from CPU 240
# INFO:pynbody.snapshot.ramses:Loading data from CPU 262
# INFO:pynbody.snapshot.ramses:Loading data from CPU 21
# INFO:pynbody.snapshot.ramses:Loading data from CPU 43
# INFO:pynbody.snapshot.ramses:Loading data from CPU 65
# INFO:pynbody.snapshot.ramses:Loading data from CPU 87
# INFO:pynbody.snapshot.ramses:Loading data from CPU 109
# INFO:pynbody.snapshot.ramses:Loading data from CPU 131
# INFO:pynbody.snapshot.ramses:Loading data from CPU 153
# INFO:pynbody.snapshot.ramses:Loading data from CPU 175
# INFO:pynbody.snapshot.ramses:Loading data from CPU 197
# INFO:pynbody.snapshot.ramses:Loading data from CPU 219
# INFO:pynbody.snapshot.ramses:Loading data from CPU 241
# INFO:pynbody.snapshot.ramses:Loading data from CPU 263
# INFO:pynbody.snapshot.ramses:Loading data from CPU 22
# INFO:pynbody.snapshot.ramses:Loading data from CPU 44
# INFO:pynbody.snapshot.ramses:Loading data from CPU 66
# INFO:pynbody.snapshot.ramses:Loading data from CPU 88
# INFO:pynbody.snapshot.ramses:Loading data from CPU 110
# INFO:pynbody.snapshot.ramses:Loading data from CPU 132
# INFO:pynbody.snapshot.ramses:Loading data from CPU 154
# INFO:pynbody.snapshot.ramses:Loading data from CPU 176
# INFO:pynbody.snapshot:Converting vel units from 2.70e+08 cm s**-1 to km s**-1
# INFO:pynbody.snapshot.ramses:Loading data from CPU 198
# INFO:pynbody.snapshot.ramses:Loading data from CPU 220
# INFO:pynbody.snapshot.ramses:Loading data from CPU 242
# INFO:pynbody.snapshot.ramses:Loading data from CPU 264
# INFO:pynbody.snapshot.ramses:Loading data from CPU 441
# INFO:pynbody.snapshot.ramses:Loading data from CPU 265
# INFO:pynbody.snapshot.ramses:Loading data from CPU 463
# INFO:pynbody.snapshot.ramses:Loading data from CPU 419
# INFO:pynbody.snapshot.ramses:Loading data from CPU 507
# INFO:pynbody.snapshot.ramses:Loading data from CPU 287
# INFO:pynbody.snapshot.ramses:Loading data from CPU 397
# INFO:pynbody.snapshot.ramses:Loading data from CPU 375
# INFO:pynbody.snapshot.ramses:Loading data from CPU 485
# INFO:pynbody.snapshot.ramses:Loading data from CPU 331
# INFO:pynbody.snapshot.ramses:Loading data from CPU 353
# INFO:pynbody.snapshot.ramses:Loading data from CPU 309
# INFO:pynbody.snapshot.ramses:Loading data from CPU 442
# INFO:pynbody.snapshot.ramses:Loading data from CPU 266
# INFO:pynbody.snapshot.ramses:Loading data from CPU 464
# INFO:pynbody.snapshot.ramses:Loading data from CPU 420
# INFO:pynbody.snapshot.ramses:Loading data from CPU 508
# INFO:pynbody.snapshot.ramses:Loading data from CPU 288
# INFO:pynbody.snapshot.ramses:Loading data from CPU 398
# INFO:pynbody.snapshot.ramses:Loading data from CPU 376
# INFO:pynbody.snapshot.ramses:Loading data from CPU 486
# INFO:pynbody.snapshot.ramses:Loading data from CPU 332
# INFO:pynbody.snapshot.ramses:Loading data from CPU 354
# INFO:pynbody.snapshot.ramses:Loading data from CPU 310
# INFO:pynbody.snapshot.ramses:Loading data from CPU 443
# INFO:pynbody.snapshot.ramses:Loading data from CPU 267
# INFO:pynbody.snapshot.ramses:Loading data from CPU 465
# INFO:pynbody.snapshot.ramses:Loading data from CPU 421
# INFO:pynbody.snapshot.ramses:Loading data from CPU 509
# INFO:pynbody.snapshot.ramses:Loading data from CPU 289
# INFO:pynbody.snapshot.ramses:Loading data from CPU 399
# INFO:pynbody.snapshot.ramses:Loading data from CPU 377
# INFO:pynbody.snapshot.ramses:Loading data from CPU 487
# INFO:pynbody.snapshot.ramses:Loading data from CPU 333
# INFO:pynbody.snapshot.ramses:Loading data from CPU 355
# INFO:pynbody.snapshot.ramses:Loading data from CPU 311
# INFO:pynbody.snapshot.ramses:Loading data from CPU 444
# INFO:pynbody.snapshot.ramses:Loading data from CPU 268
# INFO:pynbody.snapshot.ramses:Loading data from CPU 466
# INFO:pynbody.snapshot.ramses:Loading data from CPU 422
# INFO:pynbody.snapshot.ramses:Loading data from CPU 510
# INFO:pynbody.snapshot.ramses:Loading data from CPU 290
# INFO:pynbody.snapshot.ramses:Loading data from CPU 400
# INFO:pynbody.snapshot.ramses:Loading data from CPU 378
# INFO:pynbody.snapshot.ramses:Loading data from CPU 488
# INFO:pynbody.snapshot.ramses:Loading data from CPU 334
# INFO:pynbody.snapshot.ramses:Loading data from CPU 356
# INFO:pynbody.snapshot.ramses:Loading data from CPU 312
# INFO:pynbody.snapshot.ramses:Loading data from CPU 445
# INFO:pynbody.snapshot.ramses:Loading data from CPU 269
# INFO:pynbody.snapshot.ramses:Loading data from CPU 467
# INFO:pynbody.snapshot.ramses:Loading data from CPU 423
# INFO:pynbody.snapshot.ramses:Loading data from CPU 511
# INFO:pynbody.snapshot.ramses:Loading data from CPU 291
# INFO:pynbody.snapshot.ramses:Loading data from CPU 401
# INFO:pynbody.snapshot.ramses:Loading data from CPU 379
# INFO:pynbody.snapshot.ramses:Loading data from CPU 489
# INFO:pynbody.snapshot.ramses:Loading data from CPU 335
# INFO:pynbody.snapshot.ramses:Loading data from CPU 357
# INFO:pynbody.snapshot.ramses:Loading data from CPU 313
# INFO:pynbody.snapshot.ramses:Loading data from CPU 446
# INFO:pynbody.snapshot.ramses:Loading data from CPU 270
# INFO:pynbody.snapshot.ramses:Loading data from CPU 468
# INFO:pynbody.snapshot.ramses:Loading data from CPU 424
# INFO:pynbody.snapshot.ramses:Loading data from CPU 512
# INFO:pynbody.snapshot.ramses:Loading data from CPU 292
# INFO:pynbody.snapshot.ramses:Loading data from CPU 402
# INFO:pynbody.snapshot.ramses:Loading data from CPU 380
# INFO:pynbody.snapshot.ramses:Loading data from CPU 490
# INFO:pynbody.snapshot.ramses:Loading data from CPU 336
# INFO:pynbody.snapshot.ramses:Loading data from CPU 358
# INFO:pynbody.snapshot.ramses:Loading data from CPU 314
# INFO:pynbody.snapshot.ramses:Loading data from CPU 447
# INFO:pynbody.snapshot.ramses:Loading data from CPU 271
# INFO:pynbody.snapshot.ramses:Loading data from CPU 469
# INFO:pynbody.snapshot.ramses:Loading data from CPU 425
# INFO:pynbody.snapshot.ramses:Loading data from CPU 513
# INFO:pynbody.snapshot.ramses:Loading data from CPU 293
# INFO:pynbody.snapshot.ramses:Loading data from CPU 403
# INFO:pynbody.snapshot.ramses:Loading data from CPU 381
# INFO:pynbody.snapshot.ramses:Loading data from CPU 491
# INFO:pynbody.snapshot.ramses:Loading data from CPU 337
# INFO:pynbody.snapshot.ramses:Loading data from CPU 359
# INFO:pynbody.snapshot.ramses:Loading data from CPU 315
# INFO:pynbody.snapshot.ramses:Loading data from CPU 448
# INFO:pynbody.snapshot.ramses:Loading data from CPU 272
# INFO:pynbody.snapshot.ramses:Loading data from CPU 470
# INFO:pynbody.snapshot.ramses:Loading data from CPU 426
# INFO:pynbody.snapshot.ramses:Loading data from CPU 514
# INFO:pynbody.snapshot.ramses:Loading data from CPU 294
# INFO:pynbody.snapshot.ramses:Loading data from CPU 404
# INFO:pynbody.snapshot.ramses:Loading data from CPU 382
# INFO:pynbody.snapshot.ramses:Loading data from CPU 492
# INFO:pynbody.snapshot.ramses:Loading data from CPU 338
# INFO:pynbody.snapshot.ramses:Loading data from CPU 360
# INFO:pynbody.snapshot.ramses:Loading data from CPU 316
# INFO:pynbody.snapshot.ramses:Loading data from CPU 449
# INFO:pynbody.snapshot.ramses:Loading data from CPU 273
# INFO:pynbody.snapshot.ramses:Loading data from CPU 471
# INFO:pynbody.snapshot.ramses:Loading data from CPU 427
# INFO:pynbody.snapshot.ramses:Loading data from CPU 515
# INFO:pynbody.snapshot.ramses:Loading data from CPU 295
# INFO:pynbody.snapshot.ramses:Loading data from CPU 405
# INFO:pynbody.snapshot.ramses:Loading data from CPU 383
# INFO:pynbody.snapshot.ramses:Loading data from CPU 493
# INFO:pynbody.snapshot.ramses:Loading data from CPU 339
# INFO:pynbody.snapshot.ramses:Loading data from CPU 361
# INFO:pynbody.snapshot.ramses:Loading data from CPU 317
# INFO:pynbody.snapshot.ramses:Loading data from CPU 450
# INFO:pynbody.snapshot.ramses:Loading data from CPU 274
# INFO:pynbody.snapshot.ramses:Loading data from CPU 472
# INFO:pynbody.snapshot.ramses:Loading data from CPU 428
# INFO:pynbody.snapshot.ramses:Loading data from CPU 516
# INFO:pynbody.snapshot.ramses:Loading data from CPU 296
# INFO:pynbody.snapshot.ramses:Loading data from CPU 406
# INFO:pynbody.snapshot.ramses:Loading data from CPU 384
# INFO:pynbody.snapshot.ramses:Loading data from CPU 494
# INFO:pynbody.snapshot.ramses:Loading data from CPU 340
# INFO:pynbody.snapshot.ramses:Loading data from CPU 362
# INFO:pynbody.snapshot.ramses:Loading data from CPU 318
# INFO:pynbody.snapshot:Converting tv units from 2.70e+08 cm s**-1 to km s**-1
# INFO:pynbody.snapshot.ramses:Loading data from CPU 451
# INFO:pynbody.snapshot.ramses:Loading data from CPU 275
# INFO:pynbody.snapshot.ramses:Loading data from CPU 473
# INFO:pynbody.snapshot.ramses:Loading data from CPU 429
# INFO:pynbody.snapshot.ramses:Loading data from CPU 517
# INFO:pynbody.snapshot.ramses:Loading data from CPU 297
# INFO:pynbody.snapshot.ramses:Loading data from CPU 407
# INFO:pynbody.snapshot.ramses:Loading data from CPU 385
# INFO:pynbody.snapshot.ramses:Loading data from CPU 495
# INFO:pynbody.snapshot.ramses:Loading data from CPU 341
# INFO:pynbody.snapshot.ramses:Loading data from CPU 363
# INFO:pynbody.snapshot.ramses:Loading data from CPU 319
# INFO:pynbody.snapshot.ramses:Loading data from CPU 452
# INFO:pynbody.snapshot.ramses:Loading data from CPU 276
# INFO:pynbody.snapshot.ramses:Loading data from CPU 474
# INFO:pynbody.snapshot.ramses:Loading data from CPU 430
# INFO:pynbody.snapshot.ramses:Loading data from CPU 518
# INFO:pynbody.snapshot.ramses:Loading data from CPU 298
# INFO:pynbody.snapshot.ramses:Loading data from CPU 408
# INFO:pynbody.snapshot.ramses:Loading data from CPU 386
# INFO:pynbody.snapshot.ramses:Loading data from CPU 496
# INFO:pynbody.snapshot.ramses:Loading data from CPU 342
# INFO:pynbody.snapshot.ramses:Loading data from CPU 364
# INFO:pynbody.snapshot.ramses:Loading data from CPU 320
# INFO:pynbody.snapshot.ramses:Loading data from CPU 453
# INFO:pynbody.snapshot.ramses:Loading data from CPU 277
# INFO:pynbody.snapshot.ramses:Loading data from CPU 475
# INFO:pynbody.snapshot.ramses:Loading data from CPU 431
# INFO:pynbody.snapshot.ramses:Loading data from CPU 519
# INFO:pynbody.snapshot.ramses:Loading data from CPU 299
# INFO:pynbody.snapshot.ramses:Loading data from CPU 409
# INFO:pynbody.snapshot.ramses:Loading data from CPU 387
# INFO:pynbody.snapshot.ramses:Loading data from CPU 497
# INFO:pynbody.snapshot.ramses:Loading data from CPU 343
# INFO:pynbody.snapshot.ramses:Loading data from CPU 365
# INFO:pynbody.snapshot.ramses:Loading data from CPU 321
# INFO:pynbody.snapshot.ramses:Loading data from CPU 454
# INFO:pynbody.snapshot.ramses:Loading data from CPU 278
# INFO:pynbody.snapshot.ramses:Loading data from CPU 476
# INFO:pynbody.snapshot.ramses:Loading data from CPU 432
# INFO:pynbody.snapshot.ramses:Loading data from CPU 520
# INFO:pynbody.snapshot.ramses:Loading data from CPU 300
# INFO:pynbody.snapshot.ramses:Loading data from CPU 410
# INFO:pynbody.snapshot.ramses:Loading data from CPU 388
# INFO:pynbody.snapshot.ramses:Loading data from CPU 498
# INFO:pynbody.snapshot.ramses:Loading data from CPU 344
# INFO:pynbody.snapshot.ramses:Loading data from CPU 366
# INFO:pynbody.snapshot.ramses:Loading data from CPU 322
# INFO:pynbody.snapshot.ramses:Loading data from CPU 455
# INFO:pynbody.snapshot.ramses:Loading data from CPU 279
# INFO:pynbody.snapshot.ramses:Loading data from CPU 477
# INFO:pynbody.snapshot.ramses:Loading data from CPU 433
# INFO:pynbody.snapshot.ramses:Loading data from CPU 521
# INFO:pynbody.snapshot.ramses:Loading data from CPU 301
# INFO:pynbody.snapshot.ramses:Loading data from CPU 411
# INFO:pynbody.snapshot.ramses:Loading data from CPU 389
# INFO:pynbody.snapshot.ramses:Loading data from CPU 499
# INFO:pynbody.snapshot.ramses:Loading data from CPU 345
# INFO:pynbody.snapshot.ramses:Loading data from CPU 367
# INFO:pynbody.snapshot.ramses:Loading data from CPU 323
# INFO:pynbody.snapshot.ramses:Loading data from CPU 456
# INFO:pynbody.snapshot.ramses:Loading data from CPU 280
# INFO:pynbody.snapshot.ramses:Loading data from CPU 478
# INFO:pynbody.snapshot.ramses:Loading data from CPU 434
# INFO:pynbody.snapshot.ramses:Loading data from CPU 522
# INFO:pynbody.snapshot.ramses:Loading data from CPU 302
# INFO:pynbody.snapshot.ramses:Loading data from CPU 412
# INFO:pynbody.snapshot.ramses:Loading data from CPU 390
# INFO:pynbody.snapshot.ramses:Loading data from CPU 500
# INFO:pynbody.snapshot.ramses:Loading data from CPU 346
# INFO:pynbody.snapshot.ramses:Loading data from CPU 368
# INFO:pynbody.snapshot.ramses:Loading data from CPU 324
# INFO:pynbody.snapshot.ramses:Loading data from CPU 457
# INFO:pynbody.snapshot.ramses:Loading data from CPU 281
# INFO:pynbody.snapshot.ramses:Loading data from CPU 479
# INFO:pynbody.snapshot.ramses:Loading data from CPU 435
# INFO:pynbody.snapshot.ramses:Loading data from CPU 523
# INFO:pynbody.snapshot.ramses:Loading data from CPU 303
# INFO:pynbody.snapshot.ramses:Loading data from CPU 413
# INFO:pynbody.snapshot.ramses:Loading data from CPU 391
# INFO:pynbody.snapshot.ramses:Loading data from CPU 501
# INFO:pynbody.snapshot.ramses:Loading data from CPU 347
# INFO:pynbody.snapshot.ramses:Loading data from CPU 369
# INFO:pynbody.snapshot.ramses:Loading data from CPU 325
# INFO:pynbody.snapshot.ramses:Loading data from CPU 458
# INFO:pynbody.snapshot.ramses:Loading data from CPU 282
# INFO:pynbody.snapshot.ramses:Loading data from CPU 480
# INFO:pynbody.snapshot.ramses:Loading data from CPU 436
# INFO:pynbody.snapshot.ramses:Loading data from CPU 524
# INFO:pynbody.snapshot.ramses:Loading data from CPU 304
# INFO:pynbody.snapshot.ramses:Loading data from CPU 414
# INFO:pynbody.snapshot.ramses:Loading data from CPU 392
# INFO:pynbody.snapshot.ramses:Loading data from CPU 502
# INFO:pynbody.snapshot.ramses:Loading data from CPU 348
# INFO:pynbody.snapshot.ramses:Loading data from CPU 370
# INFO:pynbody.snapshot.ramses:Loading data from CPU 326
# INFO:pynbody.snapshot.ramses:Loading data from CPU 459
# INFO:pynbody.snapshot.ramses:Loading data from CPU 283
# INFO:pynbody.snapshot.ramses:Loading data from CPU 481
# INFO:pynbody.snapshot.ramses:Loading data from CPU 437
# INFO:pynbody.snapshot.ramses:Loading data from CPU 525
# INFO:pynbody.snapshot.ramses:Loading data from CPU 305
# INFO:pynbody.snapshot.ramses:Loading data from CPU 415
# INFO:pynbody.snapshot.ramses:Loading data from CPU 393
# INFO:pynbody.snapshot.ramses:Loading data from CPU 503
# INFO:pynbody.snapshot.ramses:Loading data from CPU 349
# INFO:pynbody.snapshot.ramses:Loading data from CPU 371
# INFO:pynbody.snapshot.ramses:Loading data from CPU 327
# INFO:pynbody.snapshot.ramses:Loading data from CPU 460
# INFO:pynbody.snapshot.ramses:Loading data from CPU 284
# INFO:pynbody.snapshot.ramses:Loading data from CPU 482
# INFO:pynbody.snapshot.ramses:Loading data from CPU 438
# INFO:pynbody.snapshot.ramses:Loading data from CPU 526
# INFO:pynbody.snapshot.ramses:Loading data from CPU 306
# INFO:pynbody.snapshot.ramses:Loading data from CPU 416
# INFO:pynbody.snapshot.ramses:Loading data from CPU 394
# INFO:pynbody.snapshot.ramses:Loading data from CPU 504
# INFO:pynbody.snapshot.ramses:Loading data from CPU 350
# INFO:pynbody.snapshot.ramses:Loading data from CPU 372
# INFO:pynbody.snapshot.ramses:Loading data from CPU 328
# INFO:pynbody.snapshot.ramses:Loading data from CPU 461
# INFO:pynbody.snapshot.ramses:Loading data from CPU 285
# INFO:pynbody.snapshot.ramses:Loading data from CPU 483
# INFO:pynbody.snapshot.ramses:Loading data from CPU 439
# INFO:pynbody.snapshot.ramses:Loading data from CPU 527
# INFO:pynbody.snapshot.ramses:Loading data from CPU 307
# INFO:pynbody.snapshot.ramses:Loading data from CPU 417
# INFO:pynbody.snapshot.ramses:Loading data from CPU 395
# INFO:pynbody.snapshot.ramses:Loading data from CPU 505
# INFO:pynbody.snapshot.ramses:Loading data from CPU 351
# INFO:pynbody.snapshot.ramses:Loading data from CPU 373
# INFO:pynbody.snapshot.ramses:Loading data from CPU 329
# INFO:pynbody.snapshot:Converting rho units from 1.84e-27 g cm**-3 to Msol kpc**-3
# INFO:pynbody.snapshot.ramses:Loading data from CPU 462
# INFO:pynbody.snapshot.ramses:Loading data from CPU 286
# INFO:pynbody.snapshot.ramses:Loading data from CPU 484
# INFO:pynbody.snapshot.ramses:Loading data from CPU 440
# INFO:pynbody.snapshot.ramses:Loading data from CPU 528
# INFO:pynbody.snapshot.ramses:Loading data from CPU 308
# INFO:pynbody.snapshot.ramses:Loading data from CPU 418
# INFO:pynbody.snapshot.ramses:Loading data from CPU 396
# INFO:pynbody.snapshot.ramses:Loading data from CPU 506
# INFO:pynbody.snapshot.ramses:Loading data from CPU 352
# INFO:pynbody.snapshot.ramses:Loading data from CPU 374
# INFO:pynbody.snapshot.ramses:Loading data from CPU 330
# INFO:pynbody.snapshot.ramses:Loading data from CPU 705
# INFO:pynbody.snapshot.ramses:Loading data from CPU 551
# INFO:pynbody.snapshot.ramses:Loading data from CPU 727
# INFO:pynbody.snapshot.ramses:Loading data from CPU 683
# INFO:pynbody.snapshot.ramses:Loading data from CPU 749
# INFO:pynbody.snapshot.ramses:Loading data from CPU 573
# INFO:pynbody.snapshot.ramses:Loading data from CPU 661
# INFO:pynbody.snapshot.ramses:Loading data from CPU 617
# INFO:pynbody.snapshot.ramses:Loading data from CPU 771
# INFO:pynbody.snapshot.ramses:Loading data from CPU 639
# INFO:pynbody.snapshot.ramses:Loading data from CPU 595
# INFO:pynbody.snapshot.ramses:Loading data from CPU 529
# INFO:pynbody.snapshot.ramses:Loading data from CPU 706
# INFO:pynbody.snapshot.ramses:Loading data from CPU 552
# INFO:pynbody.snapshot.ramses:Loading data from CPU 728
# INFO:pynbody.snapshot.ramses:Loading data from CPU 684
# INFO:pynbody.snapshot.ramses:Loading data from CPU 750
# INFO:pynbody.snapshot.ramses:Loading data from CPU 574
# INFO:pynbody.snapshot.ramses:Loading data from CPU 662
# INFO:pynbody.snapshot.ramses:Loading data from CPU 618
# INFO:pynbody.snapshot.ramses:Loading data from CPU 772
# INFO:pynbody.snapshot.ramses:Loading data from CPU 640
# INFO:pynbody.snapshot.ramses:Loading data from CPU 596
# INFO:pynbody.snapshot.ramses:Loading data from CPU 530
# INFO:pynbody.snapshot.ramses:Loading data from CPU 707
# INFO:pynbody.snapshot.ramses:Loading data from CPU 553
# INFO:pynbody.snapshot.ramses:Loading data from CPU 729
# INFO:pynbody.snapshot.ramses:Loading data from CPU 685
# INFO:pynbody.snapshot.ramses:Loading data from CPU 751
# INFO:pynbody.snapshot.ramses:Loading data from CPU 575
# INFO:pynbody.snapshot.ramses:Loading data from CPU 663
# INFO:pynbody.snapshot.ramses:Loading data from CPU 619
# INFO:pynbody.snapshot.ramses:Loading data from CPU 773
# INFO:pynbody.snapshot.ramses:Loading data from CPU 641
# INFO:pynbody.snapshot.ramses:Loading data from CPU 597
# INFO:pynbody.snapshot.ramses:Loading data from CPU 531
# INFO:pynbody.snapshot.ramses:Loading data from CPU 708
# INFO:pynbody.snapshot.ramses:Loading data from CPU 554
# INFO:pynbody.snapshot.ramses:Loading data from CPU 730
# INFO:pynbody.snapshot.ramses:Loading data from CPU 686
# INFO:pynbody.snapshot.ramses:Loading data from CPU 752
# INFO:pynbody.snapshot.ramses:Loading data from CPU 576
# INFO:pynbody.snapshot.ramses:Loading data from CPU 664
# INFO:pynbody.snapshot.ramses:Loading data from CPU 620
# INFO:pynbody.snapshot.ramses:Loading data from CPU 774
# INFO:pynbody.snapshot.ramses:Loading data from CPU 642
# INFO:pynbody.snapshot.ramses:Loading data from CPU 598
# INFO:pynbody.snapshot.ramses:Loading data from CPU 532
# INFO:pynbody.snapshot.ramses:Loading data from CPU 709
# INFO:pynbody.snapshot.ramses:Loading data from CPU 555
# INFO:pynbody.snapshot.ramses:Loading data from CPU 731
# INFO:pynbody.snapshot.ramses:Loading data from CPU 687
# INFO:pynbody.snapshot.ramses:Loading data from CPU 753
# INFO:pynbody.snapshot.ramses:Loading data from CPU 577
# INFO:pynbody.snapshot.ramses:Loading data from CPU 665
# INFO:pynbody.snapshot.ramses:Loading data from CPU 621
# INFO:pynbody.snapshot.ramses:Loading data from CPU 775
# INFO:pynbody.snapshot.ramses:Loading data from CPU 643
# INFO:pynbody.snapshot.ramses:Loading data from CPU 599
# INFO:pynbody.snapshot.ramses:Loading data from CPU 533
# INFO:pynbody.snapshot.ramses:Loading data from CPU 710
# INFO:pynbody.snapshot.ramses:Loading data from CPU 556
# INFO:pynbody.snapshot.ramses:Loading data from CPU 732
# INFO:pynbody.snapshot.ramses:Loading data from CPU 688
# INFO:pynbody.snapshot.ramses:Loading data from CPU 754
# INFO:pynbody.snapshot.ramses:Loading data from CPU 578
# INFO:pynbody.snapshot.ramses:Loading data from CPU 666
# INFO:pynbody.snapshot.ramses:Loading data from CPU 622
# INFO:pynbody.snapshot.ramses:Loading data from CPU 776
# INFO:pynbody.snapshot.ramses:Loading data from CPU 644
# INFO:pynbody.snapshot.ramses:Loading data from CPU 600
# INFO:pynbody.snapshot.ramses:Loading data from CPU 534
# INFO:pynbody.snapshot.ramses:Loading data from CPU 711
# INFO:pynbody.snapshot.ramses:Loading data from CPU 557
# INFO:pynbody.snapshot.ramses:Loading data from CPU 733
# INFO:pynbody.snapshot.ramses:Loading data from CPU 689
# INFO:pynbody.snapshot.ramses:Loading data from CPU 755
# INFO:pynbody.snapshot.ramses:Loading data from CPU 579
# INFO:pynbody.snapshot.ramses:Loading data from CPU 667
# INFO:pynbody.snapshot.ramses:Loading data from CPU 623
# INFO:pynbody.snapshot.ramses:Loading data from CPU 777
# INFO:pynbody.snapshot.ramses:Loading data from CPU 645
# INFO:pynbody.snapshot.ramses:Loading data from CPU 601
# INFO:pynbody.snapshot.ramses:Loading data from CPU 535
# INFO:pynbody.snapshot.ramses:Loading data from CPU 712
# INFO:pynbody.snapshot.ramses:Loading data from CPU 558
# INFO:pynbody.snapshot.ramses:Loading data from CPU 734
# INFO:pynbody.snapshot.ramses:Loading data from CPU 690
# INFO:pynbody.snapshot.ramses:Loading data from CPU 756
# INFO:pynbody.snapshot.ramses:Loading data from CPU 580
# INFO:pynbody.snapshot.ramses:Loading data from CPU 668
# INFO:pynbody.snapshot.ramses:Loading data from CPU 624
# INFO:pynbody.snapshot.ramses:Loading data from CPU 778
# INFO:pynbody.snapshot.ramses:Loading data from CPU 646
# INFO:pynbody.snapshot.ramses:Loading data from CPU 602
# INFO:pynbody.snapshot.ramses:Loading data from CPU 536
# INFO:pynbody.snapshot.ramses:Loading data from CPU 713
# INFO:pynbody.snapshot.ramses:Loading data from CPU 559
# INFO:pynbody.snapshot.ramses:Loading data from CPU 735
# INFO:pynbody.snapshot.ramses:Loading data from CPU 691
# INFO:pynbody.snapshot.ramses:Loading data from CPU 757
# INFO:pynbody.snapshot.ramses:Loading data from CPU 581
# INFO:pynbody.snapshot.ramses:Loading data from CPU 669
# INFO:pynbody.snapshot.ramses:Loading data from CPU 625
# INFO:pynbody.snapshot.ramses:Loading data from CPU 779
# INFO:pynbody.snapshot.ramses:Loading data from CPU 647
# INFO:pynbody.snapshot.ramses:Loading data from CPU 603
# INFO:pynbody.snapshot.ramses:Loading data from CPU 537
# INFO:pynbody.snapshot.ramses:Loading data from CPU 714
# INFO:pynbody.snapshot.ramses:Loading data from CPU 560
# INFO:pynbody.snapshot.ramses:Loading data from CPU 736
# INFO:pynbody.snapshot.ramses:Loading data from CPU 692
# INFO:pynbody.snapshot.ramses:Loading data from CPU 758
# INFO:pynbody.snapshot.ramses:Loading data from CPU 582
# INFO:pynbody.snapshot.ramses:Loading data from CPU 670
# INFO:pynbody.snapshot.ramses:Loading data from CPU 626
# INFO:pynbody.snapshot:Converting smooth units from 1.45e+24 cm to kpc
# INFO:pynbody.snapshot.ramses:Loading data from CPU 780
# INFO:pynbody.snapshot.ramses:Loading data from CPU 648
# INFO:pynbody.snapshot.ramses:Loading data from CPU 604
# INFO:pynbody.snapshot.ramses:Loading data from CPU 538
# INFO:pynbody.snapshot.ramses:Loading data from CPU 715
# INFO:pynbody.snapshot.ramses:Loading data from CPU 561
# INFO:pynbody.snapshot.ramses:Loading data from CPU 737
# INFO:pynbody.snapshot.ramses:Loading data from CPU 693
# INFO:pynbody.snapshot.ramses:Loading data from CPU 759
# INFO:pynbody.snapshot.ramses:Loading data from CPU 583
# INFO:pynbody.snapshot.ramses:Loading data from CPU 671
# INFO:pynbody.snapshot.ramses:Loading data from CPU 627
# INFO:pynbody.snapshot.ramses:Loading data from CPU 781
# INFO:pynbody.snapshot.ramses:Loading data from CPU 649
# INFO:pynbody.snapshot.ramses:Loading data from CPU 605
# INFO:pynbody.snapshot.ramses:Loading data from CPU 539
# INFO:pynbody.snapshot.ramses:Loading data from CPU 716
# INFO:pynbody.snapshot.ramses:Loading data from CPU 562
# INFO:pynbody.snapshot.ramses:Loading data from CPU 738
# INFO:pynbody.snapshot.ramses:Loading data from CPU 694
# INFO:pynbody.snapshot.ramses:Loading data from CPU 760
# INFO:pynbody.snapshot.ramses:Loading data from CPU 584
# INFO:pynbody.snapshot.ramses:Loading data from CPU 672
# INFO:pynbody.snapshot.ramses:Loading data from CPU 628
# INFO:pynbody.snapshot.ramses:Loading data from CPU 782
# INFO:pynbody.snapshot.ramses:Loading data from CPU 650
# INFO:pynbody.snapshot.ramses:Loading data from CPU 606
# INFO:pynbody.snapshot.ramses:Loading data from CPU 540
# INFO:pynbody.snapshot.ramses:Loading data from CPU 717
# INFO:pynbody.snapshot.ramses:Loading data from CPU 563
# INFO:pynbody.snapshot.ramses:Loading data from CPU 739
# INFO:pynbody.snapshot.ramses:Loading data from CPU 695
# INFO:pynbody.snapshot.ramses:Loading data from CPU 761
# INFO:pynbody.snapshot.ramses:Loading data from CPU 585
# INFO:pynbody.snapshot.ramses:Loading data from CPU 673
# INFO:pynbody.snapshot.ramses:Loading data from CPU 629
# INFO:pynbody.snapshot.ramses:Loading data from CPU 783
# INFO:pynbody.snapshot.ramses:Loading data from CPU 651
# INFO:pynbody.snapshot.ramses:Loading data from CPU 607
# INFO:pynbody.snapshot.ramses:Loading data from CPU 541
# INFO:pynbody.snapshot.ramses:Loading data from CPU 718
# INFO:pynbody.snapshot.ramses:Loading data from CPU 564
# INFO:pynbody.snapshot.ramses:Loading data from CPU 740
# INFO:pynbody.snapshot.ramses:Loading data from CPU 696
# INFO:pynbody.snapshot.ramses:Loading data from CPU 762
# INFO:pynbody.snapshot.ramses:Loading data from CPU 586
# INFO:pynbody.snapshot.ramses:Loading data from CPU 674
# INFO:pynbody.snapshot.ramses:Loading data from CPU 630
# INFO:pynbody.snapshot.ramses:Loading data from CPU 784
# INFO:pynbody.snapshot.ramses:Loading data from CPU 652
# INFO:pynbody.snapshot.ramses:Loading data from CPU 608
# INFO:pynbody.snapshot.ramses:Loading data from CPU 542
# INFO:pynbody.snapshot.ramses:Loading data from CPU 719
# INFO:pynbody.snapshot.ramses:Loading data from CPU 565
# INFO:pynbody.snapshot.ramses:Loading data from CPU 741
# INFO:pynbody.snapshot.ramses:Loading data from CPU 697
# INFO:pynbody.snapshot.ramses:Loading data from CPU 763
# INFO:pynbody.snapshot.ramses:Loading data from CPU 587
# INFO:pynbody.snapshot.ramses:Loading data from CPU 675
# INFO:pynbody.snapshot.ramses:Loading data from CPU 631
# INFO:pynbody.snapshot.ramses:Loading data from CPU 785
# INFO:pynbody.snapshot.ramses:Loading data from CPU 653
# INFO:pynbody.snapshot.ramses:Loading data from CPU 609
# INFO:pynbody.snapshot.ramses:Loading data from CPU 543
# INFO:pynbody.snapshot.ramses:Loading data from CPU 720
# INFO:pynbody.snapshot.ramses:Loading data from CPU 566
# INFO:pynbody.snapshot.ramses:Loading data from CPU 742
# INFO:pynbody.snapshot.ramses:Loading data from CPU 698
# INFO:pynbody.snapshot.ramses:Loading data from CPU 764
# INFO:pynbody.snapshot.ramses:Loading data from CPU 588
# INFO:pynbody.snapshot.ramses:Loading data from CPU 676
# INFO:pynbody.snapshot.ramses:Loading data from CPU 632
# INFO:pynbody.snapshot.ramses:Loading data from CPU 786
# INFO:pynbody.snapshot.ramses:Loading data from CPU 654
# INFO:pynbody.snapshot.ramses:Loading data from CPU 610
# INFO:pynbody.snapshot.ramses:Loading data from CPU 544
# INFO:pynbody.snapshot.ramses:Loading data from CPU 721
# INFO:pynbody.snapshot.ramses:Loading data from CPU 567
# INFO:pynbody.snapshot.ramses:Loading data from CPU 743
# INFO:pynbody.snapshot.ramses:Loading data from CPU 699
# INFO:pynbody.snapshot.ramses:Loading data from CPU 765
# INFO:pynbody.snapshot.ramses:Loading data from CPU 589
# INFO:pynbody.snapshot.ramses:Loading data from CPU 677
# INFO:pynbody.snapshot.ramses:Loading data from CPU 633
# INFO:pynbody.snapshot.ramses:Loading data from CPU 787
# INFO:pynbody.snapshot.ramses:Loading data from CPU 655
# INFO:pynbody.snapshot.ramses:Loading data from CPU 611
# INFO:pynbody.snapshot.ramses:Loading data from CPU 545
# INFO:pynbody.snapshot.ramses:Loading data from CPU 722
# INFO:pynbody.snapshot.ramses:Loading data from CPU 568
# INFO:pynbody.snapshot.ramses:Loading data from CPU 744
# INFO:pynbody.snapshot.ramses:Loading data from CPU 700
# INFO:pynbody.snapshot.ramses:Loading data from CPU 766
# INFO:pynbody.snapshot.ramses:Loading data from CPU 590
# INFO:pynbody.snapshot.ramses:Loading data from CPU 678
# INFO:pynbody.snapshot.ramses:Loading data from CPU 634
# INFO:pynbody.snapshot.ramses:Loading data from CPU 788
# INFO:pynbody.snapshot.ramses:Loading data from CPU 656
# INFO:pynbody.snapshot.ramses:Loading data from CPU 612
# INFO:pynbody.snapshot.ramses:Loading data from CPU 546
# INFO:pynbody.snapshot.ramses:Loading data from CPU 723
# INFO:pynbody.snapshot.ramses:Loading data from CPU 569
# INFO:pynbody.snapshot.ramses:Loading data from CPU 745
# INFO:pynbody.snapshot.ramses:Loading data from CPU 701
# INFO:pynbody.snapshot.ramses:Loading data from CPU 767
# INFO:pynbody.snapshot.ramses:Loading data from CPU 591
# INFO:pynbody.snapshot.ramses:Loading data from CPU 679
# INFO:pynbody.snapshot.ramses:Loading data from CPU 635
# INFO:pynbody.snapshot.ramses:Loading data from CPU 789
# INFO:pynbody.snapshot.ramses:Loading data from CPU 657
# INFO:pynbody.snapshot.ramses:Loading data from CPU 613
# INFO:pynbody.snapshot.ramses:Loading data from CPU 547
# INFO:pynbody.snapshot.ramses:Loading data from CPU 724
# INFO:pynbody.snapshot.ramses:Loading data from CPU 570
# INFO:pynbody.snapshot.ramses:Loading data from CPU 746
# INFO:pynbody.snapshot.ramses:Loading data from CPU 702
# INFO:pynbody.snapshot.ramses:Loading data from CPU 768
# INFO:pynbody.snapshot.ramses:Loading data from CPU 592
# INFO:pynbody.snapshot.ramses:Loading data from CPU 680
# INFO:pynbody.snapshot.ramses:Loading data from CPU 636
# INFO:pynbody.snapshot.ramses:Loading data from CPU 790
# INFO:pynbody.snapshot.ramses:Loading data from CPU 658
# INFO:pynbody.snapshot.ramses:Loading data from CPU 614
# INFO:pynbody.snapshot.ramses:Loading data from CPU 548
# INFO:pynbody.snapshot:Converting p units from 1.34e-10 g cm**-1 s**-2 to km**2 Msol s**-2 kpc**-3
# INFO:pynbody.snapshot.ramses:Loading data from CPU 725
# INFO:pynbody.snapshot.ramses:Loading data from CPU 571
# INFO:pynbody.snapshot.ramses:Loading data from CPU 747
# INFO:pynbody.snapshot.ramses:Loading data from CPU 703
# INFO:pynbody.snapshot.ramses:Loading data from CPU 769
# INFO:pynbody.snapshot.ramses:Loading data from CPU 593
# INFO:pynbody.snapshot.ramses:Loading data from CPU 681
# INFO:pynbody.snapshot.ramses:Loading data from CPU 637
# INFO:pynbody.snapshot.ramses:Loading data from CPU 791
# INFO:pynbody.snapshot.ramses:Loading data from CPU 659
# INFO:pynbody.snapshot.ramses:Loading data from CPU 615
# INFO:pynbody.snapshot.ramses:Loading data from CPU 549
# INFO:pynbody.snapshot.ramses:Loading data from CPU 726
# INFO:pynbody.snapshot.ramses:Loading data from CPU 572
# INFO:pynbody.snapshot.ramses:Loading data from CPU 748
# INFO:pynbody.snapshot.ramses:Loading data from CPU 704
# INFO:pynbody.snapshot.ramses:Loading data from CPU 770
# INFO:pynbody.snapshot.ramses:Loading data from CPU 594
# INFO:pynbody.snapshot.ramses:Loading data from CPU 682
# INFO:pynbody.snapshot.ramses:Loading data from CPU 638
# INFO:pynbody.snapshot.ramses:Loading data from CPU 792
# INFO:pynbody.snapshot.ramses:Loading data from CPU 660
# INFO:pynbody.snapshot.ramses:Loading data from CPU 616
# INFO:pynbody.snapshot.ramses:Loading data from CPU 550
# INFO:pynbody.snapshot.ramses:Loading data from CPU 991
# INFO:pynbody.snapshot.ramses:Loading data from CPU 815
# INFO:pynbody.snapshot.ramses:Loading data from CPU 969
# INFO:pynbody.snapshot.ramses:Loading data from CPU 881
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1013
# INFO:pynbody.snapshot.ramses:Loading data from CPU 903
# INFO:pynbody.snapshot.ramses:Loading data from CPU 947
# INFO:pynbody.snapshot.ramses:Loading data from CPU 859
# INFO:pynbody.snapshot.ramses:Loading data from CPU 793
# INFO:pynbody.snapshot.ramses:Loading data from CPU 837
# INFO:pynbody.snapshot.ramses:Loading data from CPU 925
# INFO:pynbody.snapshot.ramses:Loading data from CPU 992
# INFO:pynbody.snapshot.ramses:Loading data from CPU 816
# INFO:pynbody.snapshot.ramses:Loading data from CPU 970
# INFO:pynbody.snapshot.ramses:Loading data from CPU 882
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1014
# INFO:pynbody.snapshot.ramses:Loading data from CPU 904
# INFO:pynbody.snapshot.ramses:Loading data from CPU 948
# INFO:pynbody.snapshot.ramses:Loading data from CPU 860
# INFO:pynbody.snapshot.ramses:Loading data from CPU 794
# INFO:pynbody.snapshot.ramses:Loading data from CPU 838
# INFO:pynbody.snapshot.ramses:Loading data from CPU 926
# INFO:pynbody.snapshot.ramses:Loading data from CPU 993
# INFO:pynbody.snapshot.ramses:Loading data from CPU 817
# INFO:pynbody.snapshot.ramses:Loading data from CPU 971
# INFO:pynbody.snapshot.ramses:Loading data from CPU 883
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1015
# INFO:pynbody.snapshot.ramses:Loading data from CPU 905
# INFO:pynbody.snapshot.ramses:Loading data from CPU 949
# INFO:pynbody.snapshot.ramses:Loading data from CPU 861
# INFO:pynbody.snapshot.ramses:Loading data from CPU 795
# INFO:pynbody.snapshot.ramses:Loading data from CPU 839
# INFO:pynbody.snapshot.ramses:Loading data from CPU 927
# INFO:pynbody.snapshot.ramses:Loading data from CPU 994
# INFO:pynbody.snapshot.ramses:Loading data from CPU 818
# INFO:pynbody.snapshot.ramses:Loading data from CPU 972
# INFO:pynbody.snapshot.ramses:Loading data from CPU 884
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1016
# INFO:pynbody.snapshot.ramses:Loading data from CPU 906
# INFO:pynbody.snapshot.ramses:Loading data from CPU 950
# INFO:pynbody.snapshot.ramses:Loading data from CPU 862
# INFO:pynbody.snapshot.ramses:Loading data from CPU 796
# INFO:pynbody.snapshot.ramses:Loading data from CPU 840
# INFO:pynbody.snapshot.ramses:Loading data from CPU 928
# INFO:pynbody.snapshot.ramses:Loading data from CPU 995
# INFO:pynbody.snapshot.ramses:Loading data from CPU 819
# INFO:pynbody.snapshot.ramses:Loading data from CPU 973
# INFO:pynbody.snapshot.ramses:Loading data from CPU 885
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1017
# INFO:pynbody.snapshot.ramses:Loading data from CPU 907
# INFO:pynbody.snapshot.ramses:Loading data from CPU 951
# INFO:pynbody.snapshot.ramses:Loading data from CPU 863
# INFO:pynbody.snapshot.ramses:Loading data from CPU 797
# INFO:pynbody.snapshot.ramses:Loading data from CPU 841
# INFO:pynbody.snapshot.ramses:Loading data from CPU 929
# INFO:pynbody.snapshot.ramses:Loading data from CPU 996
# INFO:pynbody.snapshot.ramses:Loading data from CPU 820
# INFO:pynbody.snapshot.ramses:Loading data from CPU 974
# INFO:pynbody.snapshot.ramses:Loading data from CPU 886
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1018
# INFO:pynbody.snapshot.ramses:Loading data from CPU 908
# INFO:pynbody.snapshot.ramses:Loading data from CPU 952
# INFO:pynbody.snapshot.ramses:Loading data from CPU 864
# INFO:pynbody.snapshot.ramses:Loading data from CPU 798
# INFO:pynbody.snapshot.ramses:Loading data from CPU 842
# INFO:pynbody.snapshot.ramses:Loading data from CPU 930
# INFO:pynbody.snapshot.ramses:Loading data from CPU 997
# INFO:pynbody.snapshot.ramses:Loading data from CPU 821
# INFO:pynbody.snapshot.ramses:Loading data from CPU 975
# INFO:pynbody.snapshot.ramses:Loading data from CPU 887
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1019
# INFO:pynbody.snapshot.ramses:Loading data from CPU 909
# INFO:pynbody.snapshot.ramses:Loading data from CPU 953
# INFO:pynbody.snapshot.ramses:Loading data from CPU 865
# INFO:pynbody.snapshot.ramses:Loading data from CPU 799
# INFO:pynbody.snapshot.ramses:Loading data from CPU 843
# INFO:pynbody.snapshot.ramses:Loading data from CPU 931
# INFO:pynbody.snapshot.ramses:Loading data from CPU 998
# INFO:pynbody.snapshot.ramses:Loading data from CPU 822
# INFO:pynbody.snapshot.ramses:Loading data from CPU 976
# INFO:pynbody.snapshot.ramses:Loading data from CPU 888
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1020
# INFO:pynbody.snapshot.ramses:Loading data from CPU 910
# INFO:pynbody.snapshot.ramses:Loading data from CPU 954
# INFO:pynbody.snapshot.ramses:Loading data from CPU 866
# INFO:pynbody.snapshot.ramses:Loading data from CPU 800
# INFO:pynbody.snapshot.ramses:Loading data from CPU 844
# INFO:pynbody.snapshot.ramses:Loading data from CPU 932
# INFO:pynbody.snapshot.ramses:Loading data from CPU 999
# INFO:pynbody.snapshot.ramses:Loading data from CPU 823
# INFO:pynbody.snapshot.ramses:Loading data from CPU 977
# INFO:pynbody.snapshot.ramses:Loading data from CPU 889
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1021
# INFO:pynbody.snapshot.ramses:Loading data from CPU 911
# INFO:pynbody.snapshot.ramses:Loading data from CPU 955
# INFO:pynbody.snapshot.ramses:Loading data from CPU 867
# INFO:pynbody.snapshot.ramses:Loading data from CPU 801
# INFO:pynbody.snapshot.ramses:Loading data from CPU 845
# INFO:pynbody.snapshot.ramses:Loading data from CPU 933
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1000
# INFO:pynbody.snapshot.ramses:Loading data from CPU 824
# INFO:pynbody.snapshot.ramses:Loading data from CPU 978
# INFO:pynbody.snapshot.ramses:Loading data from CPU 890
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1022
# INFO:pynbody.snapshot.ramses:Loading data from CPU 912
# INFO:pynbody.snapshot.ramses:Loading data from CPU 956
# INFO:pynbody.snapshot.ramses:Loading data from CPU 868
# INFO:pynbody.snapshot.ramses:Loading data from CPU 802
# INFO:pynbody.snapshot.ramses:Loading data from CPU 846
# INFO:pynbody.snapshot.ramses:Loading data from CPU 934
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1001
# INFO:pynbody.snapshot.ramses:Loading data from CPU 825
# INFO:pynbody.snapshot.ramses:Loading data from CPU 979
# INFO:pynbody.snapshot.ramses:Loading data from CPU 891
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1023
# INFO:pynbody.snapshot.ramses:Loading data from CPU 913
# INFO:pynbody.snapshot.ramses:Loading data from CPU 957
# INFO:pynbody.snapshot.ramses:Loading data from CPU 869
# INFO:pynbody.snapshot.ramses:Loading data from CPU 803
# INFO:pynbody.snapshot.ramses:Loading data from CPU 847
# INFO:pynbody.snapshot.ramses:Loading data from CPU 935
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1002
# INFO:pynbody.snapshot.ramses:Loading data from CPU 826
# INFO:pynbody.snapshot.ramses:Loading data from CPU 980
# INFO:pynbody.snapshot.ramses:Loading data from CPU 892
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1024
# INFO:pynbody.snapshot.ramses:Loading data from CPU 914
# INFO:pynbody.snapshot.ramses:Loading data from CPU 958
# INFO:pynbody.snapshot.ramses:Loading data from CPU 870
# INFO:pynbody.snapshot.ramses:Loading data from CPU 804
# INFO:pynbody.snapshot.ramses:Loading data from CPU 848
# INFO:pynbody.snapshot.ramses:Loading data from CPU 936
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1003
# INFO:pynbody.snapshot.ramses:Loading data from CPU 827
# INFO:pynbody.snapshot.ramses:Loading data from CPU 981
# INFO:pynbody.snapshot.ramses:Loading data from CPU 893
# INFO:pynbody.snapshot.ramses:Loading data from CPU 937
# INFO:pynbody.snapshot.ramses:Loading data from CPU 915
# INFO:pynbody.snapshot.ramses:Loading data from CPU 959
# INFO:pynbody.snapshot.ramses:Loading data from CPU 871
# INFO:pynbody.snapshot.ramses:Loading data from CPU 805
# INFO:pynbody.snapshot.ramses:Loading data from CPU 849
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1004
# INFO:pynbody.snapshot.ramses:Loading data from CPU 828
# INFO:pynbody.snapshot.ramses:Loading data from CPU 982
# INFO:pynbody.snapshot.ramses:Loading data from CPU 894
# INFO:pynbody.snapshot.ramses:Loading data from CPU 938
# INFO:pynbody.snapshot.ramses:Loading data from CPU 916
# INFO:pynbody.snapshot.ramses:Loading data from CPU 960
# INFO:pynbody.snapshot.ramses:Loading data from CPU 872
# INFO:pynbody.snapshot.ramses:Loading data from CPU 806
# INFO:pynbody.snapshot.ramses:Loading data from CPU 850
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1005
# INFO:pynbody.snapshot.ramses:Loading data from CPU 829
# INFO:pynbody.snapshot.ramses:Loading data from CPU 983
# INFO:pynbody.snapshot.ramses:Loading data from CPU 895
# INFO:pynbody.snapshot.ramses:Loading data from CPU 939
# INFO:pynbody.snapshot.ramses:Loading data from CPU 917
# INFO:pynbody.snapshot.ramses:Loading data from CPU 961
# INFO:pynbody.snapshot.ramses:Loading data from CPU 873
# INFO:pynbody.snapshot.ramses:Loading data from CPU 807
# INFO:pynbody.snapshot.ramses:Loading data from CPU 851
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1006
# INFO:pynbody.snapshot.ramses:Loading data from CPU 830
# INFO:pynbody.snapshot.ramses:Loading data from CPU 984
# INFO:pynbody.snapshot.ramses:Loading data from CPU 896
# INFO:pynbody.snapshot.ramses:Loading data from CPU 940
# INFO:pynbody.snapshot.ramses:Loading data from CPU 918
# INFO:pynbody.snapshot.ramses:Loading data from CPU 962
# INFO:pynbody.snapshot.ramses:Loading data from CPU 874
# INFO:pynbody.snapshot.ramses:Loading data from CPU 808
# INFO:pynbody.snapshot.ramses:Loading data from CPU 852
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1007
# INFO:pynbody.snapshot.ramses:Loading data from CPU 831
# INFO:pynbody.snapshot.ramses:Loading data from CPU 985
# INFO:pynbody.snapshot.ramses:Loading data from CPU 897
# INFO:pynbody.snapshot.ramses:Loading data from CPU 941
# INFO:pynbody.snapshot.ramses:Loading data from CPU 919
# INFO:pynbody.snapshot.ramses:Loading data from CPU 963
# INFO:pynbody.snapshot.ramses:Loading data from CPU 875
# INFO:pynbody.snapshot.ramses:Loading data from CPU 809
# INFO:pynbody.snapshot.ramses:Loading data from CPU 853
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1008
# INFO:pynbody.snapshot.ramses:Loading data from CPU 832
# INFO:pynbody.snapshot.ramses:Loading data from CPU 986
# INFO:pynbody.snapshot.ramses:Loading data from CPU 898
# INFO:pynbody.snapshot.ramses:Loading data from CPU 942
# INFO:pynbody.snapshot.ramses:Loading data from CPU 920
# INFO:pynbody.snapshot.ramses:Loading data from CPU 964
# INFO:pynbody.snapshot.ramses:Loading data from CPU 876
# INFO:pynbody.snapshot.ramses:Loading data from CPU 810
# INFO:pynbody.snapshot.ramses:Loading data from CPU 854
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1009
# INFO:pynbody.snapshot.ramses:Loading data from CPU 833
# INFO:pynbody.snapshot.ramses:Loading data from CPU 987
# INFO:pynbody.snapshot.ramses:Loading data from CPU 899
# INFO:pynbody.snapshot.ramses:Loading data from CPU 943
# INFO:pynbody.snapshot.ramses:Loading data from CPU 921
# INFO:pynbody.snapshot.ramses:Loading data from CPU 965
# INFO:pynbody.snapshot.ramses:Loading data from CPU 877
# INFO:pynbody.snapshot.ramses:Loading data from CPU 811
# INFO:pynbody.snapshot.ramses:Loading data from CPU 855
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1010
# INFO:pynbody.snapshot.ramses:Loading data from CPU 834
# INFO:pynbody.snapshot.ramses:Loading data from CPU 988
# INFO:pynbody.snapshot.ramses:Loading data from CPU 900
# INFO:pynbody.snapshot.ramses:Loading data from CPU 944
# INFO:pynbody.snapshot.ramses:Loading data from CPU 922
# INFO:pynbody.snapshot.ramses:Loading data from CPU 966
# INFO:pynbody.snapshot.ramses:Loading data from CPU 878
# INFO:pynbody.snapshot.ramses:Loading data from CPU 812
# INFO:pynbody.snapshot.ramses:Loading data from CPU 856
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1011
# INFO:pynbody.snapshot.ramses:Loading data from CPU 835
# INFO:pynbody.snapshot.ramses:Loading data from CPU 989
# INFO:pynbody.snapshot.ramses:Loading data from CPU 901
# INFO:pynbody.snapshot.ramses:Loading data from CPU 945
# INFO:pynbody.snapshot.ramses:Loading data from CPU 923
# INFO:pynbody.snapshot.ramses:Loading data from CPU 967
# INFO:pynbody.snapshot.ramses:Loading data from CPU 879
# INFO:pynbody.snapshot.ramses:Loading data from CPU 813
# INFO:pynbody.snapshot.ramses:Loading data from CPU 857
# INFO:pynbody.snapshot.ramses:Loading data from CPU 1012
# INFO:pynbody.snapshot.ramses:Loading data from CPU 836
# INFO:pynbody.snapshot.ramses:Loading data from CPU 990
# INFO:pynbody.snapshot.ramses:Loading data from CPU 902
# INFO:pynbody.snapshot.ramses:Loading data from CPU 946
# INFO:pynbody.snapshot.ramses:Loading data from CPU 924
# INFO:pynbody.snapshot.ramses:Loading data from CPU 968
# INFO:pynbody.snapshot.ramses:Loading data from CPU 880
# INFO:pynbody.snapshot.ramses:Loading data from CPU 814
# INFO:pynbody.snapshot.ramses:Loading data from CPU 858

# %%
z = 1/s.properties['a']-1
print ("Redshift =",z)
boxsizestring = "%.2f" % s.properties['boxsize'].in_units('kpc')
boxsizestring += " kpc"
print (boxsizestring)
# Out:
# Redshift = 7.999933327855002
# 468.62 kpc

# %%
sbox = 40.0 / (1.0 + z) * 0.71 # 40 kpc comoving box
smallbox = str(sbox) + " kpc"
print(smallbox)
# Out:
# 3.1555789321351235 kpc

# %%
s.g['metal'][s.g['metal']<1e-7]    = 1e-10 # Since we divide by Z below, don't use 0.0
#s2.g['pgf'][s2.g['pgf']>(1.0-1e-10)]  = 1.0
s.g['pzf'][s.g['pzf']<1e-7]        = 1e-10
s.g['zsolar']  = s.g['metal'] * 50.0         # Solar units
s.g['pzsolar'] = s.g['pzf'] * 50.0          # Solar units

#s2.s['metal'][s2.s['metal']<1e-10]    = 1e-10
#s2.s['ppf'][s2.s['ppf']>(1.0-1e-10)]  = 1.0
#s2.s['pzf'][s2.s['pzf']<1e-10]        = 1e-10
#s2.s['zsolar']  = s2.s['metal'] * 50.0         # Solar units
#s2.s['pzsolar'] = s2.s['pzf'] * 50.0          # Solar units

# %%
gc.collect()
# Out:
# 0

# %%
# z=8, i=0 : -121.77, -104.01, -203.10
# z=8, i=265793 : -0.88, 215.56, 143.27
# z=8, i=531586 : 77.55, 54.08, 218.96
# z=8, i=797379 : 137.45, -200.82, -220.27

rx,ry,rz = -121.77, -104.01, -203.10
i=0
print(rx,ry,rz)
impData = s[pynbody.filt.Cuboid(str((rx-sbox/2.0)) + " kpc", str((ry-sbox/2.0)) + " kpc",str((rz-sbox/4.0)) + " kpc",
                                str((rx+sbox/2.0)) + " kpc", str((ry+sbox/2.0)) + " kpc",str((rz+sbox/4.0)) + " kpc")]
print(z,i)
# Out:
# -121.77 -104.01 -203.1
# 7.999933327855002 0

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax.set_xlabel(fontsize=40)
    fileOut="img_log_ax_Z-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "$Z_{\odot}$ - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="zsolar",width=smallbox,cmap="nipy_spectral", denoise=True ,av_z=False, subplot=ax,
                      log=True, vmax=1.0, vmin=1e-7, qtytitle="$log_{10}\; Z_{\odot}$", approximate_fast=False
                      ); #vmin=0.006, vmax=1.0,
    ax.set_xticks([-0.7, 0, 0.7])
    ax.set_xticklabels(['-0.7','0','0.7'])
    plt.savefig(fileOut)
    plt.close(fig)
            
    fig = plt.figure()
    ax = fig.add_subplot(111)
    fileOut="img_log_ax_PGF-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "PGF - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="pgf",width=smallbox,cmap="nipy_spectral", denoise=True ,av_z=False,subplot=ax,
                      log=True, vmax = 1.0, vmin=1e-7, qtytitle="$log_{10}\; PGF$",approximate_fast=False
                      ); #vmin=0.006, vmax=1.0,
    ax.set_xticks([-0.7, 0, 0.7])
    ax.set_xticklabels(['-0.7','0','0.7'])
    ax.set_yticks([-0.7, 0, 0.7])
    ax.set_yticklabels(['-0.7','0','0.7'])
    plt.savefig(fileOut)
    plt.close(fig)
            
    fig = plt.figure()
    ax = fig.add_subplot(111)
    fileOut="img_log_ax_PZ-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "$Z_{P, \odot}$ - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="pzsolar",width=smallbox,cmap="nipy_spectral", denoise=True ,av_z=False,subplot=ax,
                      log=True, vmax=1.0, vmin=1e-7, qtytitle="$log_{10}\; Z_{P,\odot}$", approximate_fast=False
                      ); #vmin=0.006, vmax=1.0,
            
    ax.set_xticks([-0.7, 0, 0.7])
    ax.set_xticklabels(['-0.7','0','0.7'])
    plt.savefig(fileOut)
    plt.close(fig)

    fig = plt.figure()
    ax = fig.add_subplot(111)
    fileOut="img_log_ax_Density-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "Density - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="rho",width=smallbox,cmap="terrain", denoise=True ,av_z=False,
                      log=True, approximate_fast=False,subplot=ax,qtytitle="$log_{10}\; M_{\odot}/kpc^{3}$"
                      ); #vmin=0.006, vmax=1.0,
    ax.set_yticks([-0.7, 0,0.7])
    ax.set_yticklabels(['-0.7','0','0.7'])
    plt.savefig(fileOut)
    plt.close(fig)
            
    fig = plt.figure()
    ax = fig.add_subplot(111)
    fileOut="img_log_ax_Temp-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "Temp - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="temp",width=smallbox,cmap="RdYlBu_r", denoise=True ,av_z=False,
                      log=True, approximate_fast=False,subplot=ax,qtytitle="$log_{10}\; Temp\, [K]$"
                      ); #vmin=0.006, vmax=1.0,
    plt.savefig(fileOut)  # Needed since filename=fileOut doesn't include the vel vecs
    plt.close(fig)
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    fileOut="img_log_ax_vt-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "$v_{t}$ @ z = %.1f" % z + "\nThin slice @ %s" % str(coords)
    print(titleStr)
    sph.velocity_image(impData.g, qty="tv", width=smallbox, cmap = "gist_ncar", 
                    mode='quiver', key_color='black',qtytitle="$log_{10}\; v\, km/s$",
                       key_x=0.2, key_y=0.1,quiverkey_bg_color='w',
                   density = 1.0, vector_resolution=40, vmax=1e3,subplot=ax,
                   show_cbar=True, vector_color='black')
    plt.savefig(fileOut)  # Needed since filename=fileOut doesn't include the vel vecs
    plt.close(fig)
# Out:
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.snapshot:Deriving array mass
# INFO:pynbody.sph:Rendering image on 32 threads...
# $Z_{\odot}$ - z = 8.0
# PGF - z = 8.0
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.sph:Rendering image on 32 threads...
# $Z_{P, \odot}$ - z = 8.0
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.sph:Rendering image on 32 threads...
# Density - z = 8.0
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.sph:Rendering image on 32 threads...
# Temp - z = 8.0
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.snapshot:Deriving array temp
# INFO:pynbody.sph:Rendering image on 32 threads...
# $v_{t}$ @ z = 8.0
# Thin slice @ [121.77, 104.01, 203.1]
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.sph:Rendering image on 32 threads...
# INFO:pynbody.sph:Rendering image on 32 threads...

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.yaxis.set_visible(False)
    #ax.set_xlabel(fontsize=40)
    fileOut="img_log_Z-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "$Z_{\odot}$ - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="zsolar",width=smallbox,cmap="nipy_spectral", denoise=True ,av_z=False, subplot=ax,
                      log=True, vmax=1.0, vmin=1e-7, qtytitle="$log_{10}\; Z_{\odot}$", approximate_fast=False
                      ); #vmin=0.006, vmax=1.0,
    ax.set_xticks([-0.7, 0, 0.7])
    ax.set_xticklabels(['-0.7','0','0.7'])
    plt.savefig(fileOut)
    plt.close(fig)
            
    fig = plt.figure()
    ax = fig.add_subplot(111)
    fileOut="img_log_PGF-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "PGF - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="pgf",width=smallbox,cmap="nipy_spectral", denoise=True ,av_z=False,subplot=ax,
                      log=True, vmax = 1.0, vmin=1e-7, qtytitle="$log_{10}\; PGF$",approximate_fast=False
                      ); #vmin=0.006, vmax=1.0,
    ax.set_xticks([-0.7, 0, 0.7])
    ax.set_xticklabels(['-0.7','0','0.7'])
    ax.set_yticks([-0.7, 0, 0.7])
    ax.set_yticklabels(['-0.7','0','0.7'])
    plt.savefig(fileOut)
    plt.close(fig)
            
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.yaxis.set_visible(False)
    fileOut="img_log_PZ-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "$Z_{P, \odot}$ - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="pzsolar",width=smallbox,cmap="nipy_spectral", denoise=True ,av_z=False,subplot=ax,
                      log=True, vmax=1.0, vmin=1e-7, qtytitle="$log_{10}\; Z_{P,\odot}$", approximate_fast=False
                      ); #vmin=0.006, vmax=1.0,
            
    ax.set_xticks([-0.7, 0, 0.7])
    ax.set_xticklabels(['-0.7','0','0.7'])
    plt.savefig(fileOut)
    plt.close(fig)

    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.xaxis.set_visible(False)
    fileOut="img_log_Density-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "Density - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="rho",width=smallbox,cmap="terrain", denoise=True ,av_z=False,
                      log=True, approximate_fast=False,subplot=ax,qtytitle="$log_{10}\; M_{\odot}/kpc^{3}$"
                      ); #vmin=0.006, vmax=1.0,
    ax.set_yticks([-0.7, 0,0.7])
    ax.set_yticklabels(['-0.7','0','0.7'])
    plt.savefig(fileOut)
    plt.close(fig)
            
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    fileOut="img_log_Temp-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "Temp - z = %.1lf" % z# + "\n[%.2lf %.2lf %.2lf]"%(rx,ry,rz)
    print (titleStr)
    sph.image(impData.g,qty="temp",width=smallbox,cmap="RdYlBu_r", denoise=True ,av_z=False,
                      log=True, approximate_fast=False,subplot=ax,qtytitle="$log_{10}\; Temp\, [K]$"
                      ); #vmin=0.006, vmax=1.0,
    plt.savefig(fileOut)  # Needed since filename=fileOut doesn't include the vel vecs
    plt.close(fig)
    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    fileOut="img_log_vt-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "$v_{t}$ @ z = %.1f" % z + "\nThin slice @ %s" % str(coords)
    print(titleStr)
    sph.velocity_image(impData.g, qty="tv", width=smallbox, cmap = "gist_ncar", 
                    mode='quiver', key_color='black',qtytitle="$log_{10}\; v\, km/s$",
                       key_x=0.2, key_y=0.1,quiverkey_bg_color='w',
                   density = 1.0, vector_resolution=40, vmax=1e3,subplot=ax,
                   show_cbar=True, vector_color='black')
    plt.savefig(fileOut)  # Needed since filename=fileOut doesn't include the vel vecs
    plt.close(fig)

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    fileOut="img_vt-z=%.1lf-%i.pdf"% (z,i)
    titleStr = "$v_{t}$ @ z = %.1f" % z + "\nThin slice @ %s" % str(coords)
    print(titleStr)
    vi = pynbody.plot.sph.velocity_image(impData.g, qty="tv", width=smallbox, cmap = "gist_ncar", 
                    mode='quiver', key_color='black',qtytitle="$v\, km/s$",
                       key_x=0.2, key_y=0.1,quiverkey_bg_color='w',
                   density = 1.0, vector_resolution=40, vmax=1e3,subplot=ax,
                   show_cbar=True, vector_color='black')
    plt.show()

#    plt.savefig(fileOut)  # Needed since filename=fileOut doesn't include the vel vecs
#    plt.close(fig)

# %%
coords= [-rx,-ry,-rz] # Translation requires negative of the coord
with pynbody.transformation.translate(impData,coords):
    sph.image(impData.g,qty="temp",width=smallbox,cmap="RdYlBu_r", denoise=True ,av_z=False,
                      log=True, approximate_fast=False,qtytitle="$log_{10}\; Temp\, [K]$"
                      ); #vmin=0.006, vmax=1.0,

# %%
from matplotlib.ticker import LogFormatterExponent # RS
from matplotlib.ticker import ScalarFormatter # RS
